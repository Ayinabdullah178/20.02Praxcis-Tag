# %% [markdown]
# ## Praxces Aufgabe

# %%
import pandas as pd
import datetime

# %%
data=pd.read_excel("Daten Praxisaufgabe.xlsx")
data["Monat"]=data["Produktionsdatum"].dt.month
data["year"]=data["Produktionsdatum"].dt.year
data#=pd.DataFrame(data)
# Out:
#      Produktionsdatum  Produkttyp                          Produktname  \
# 0          2021-09-18          10                        CheeseStation
# 1          2020-05-01           3    Virtual Reality Nose Hair Trimmer
# 2          2021-11-15           1          Wi-Fi Smelly Socks Detector
# 3          2021-08-04           7             Solar-Powered Rain Cloud
# 4          2021-01-08           6  Electric Toothbrush Karaoke Machine
# ...               ...         ...                                  ...
# 2529       2021-08-08           5                       Selfie Toaster
# 2530       2022-08-14           7             Solar-Powered Rain Cloud
# 2531       2022-10-03           6  Electric Toothbrush Karaoke Machine
# 2532       2022-11-11           5                       Selfie Toaster
# 2533       2022-09-30           8              Quantum Potato Computer
#
#       Produzierte Einheiten  Arbeitskosten  Materialkosten  Sonstige Kosten  \
# ...

# %%
neu_data=data.groupby("year")
neu_data=pd.DataFrame(neu_data)
neu_data
# Out:
#       0                                                  1
# 0  2020       Produktionsdatum  Produkttyp             ...
# 1  2021       Produktionsdatum  Produkttyp             ...
# 2  2022       Produktionsdatum  Produkttyp             ...

# %%
data=datetime.datetime.time(data,"%m.%Y")
#data=datetime.datetime.strftime(data,"%m.%Y")
#data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 data=datetime.datetime.time(data,"%m.%Y")
#       2 #data=datetime.datetime.strftime(data,"%m.%Y")
#       3 #data
#
# TypeError: descriptor 'time' for 'datetime.datetime' objects doesn't apply to a 'DataFrame' object
